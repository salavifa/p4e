# %% [markdown]
# * # General intro
#
# * # Python basics
#
# * # Functions, Files and Dictionaries
#
# * # Data Collection and processing
#
# * # Databases, API client/server
#
# * # Finally find or create an interesting group project

# %% [markdown]
# ### I will be using MarkDown and Jupyter noebook as the *scratch pad* and *whiteboard*
# ![image.png](attachment:image.png)
# * reference https://www.markdownguide.org/getting-started

# %% [markdown]
# # Reference book:
#
# # Foundations of Python Programming
#
#
# This interactive book is a product of the [Runestone Interactive](https://blog.runestone.academy/) Project.
#
# * This book is based on the [Original](https://www.openbookproject.net/thinkcs/python/english2e/) work by: Jeffrey Elkner, Allen B. Downey, and Chris Meyers, the Interactive edition of How to Think Like a Computer Scientist by Brad Miller, David Ranum and many more and Programs Information and People by Paul Resnick
#
# * Activecode based on [Skulpt](https://skulpt.org/)
#
# * Codelens based on Online [Python Tutor](https://pythontutor.com/)
#
# * Many contributions from the CSLearning4U research group at Georgia Tech.
#
# * ACM-SIGCSE for the special projects grant that funded our student Isaac Dontje Lindell for the summer of 2013.
#     NSF
#
# The Runestone Interactive tools are open source and we encourage you to contact us, or grab a copy from [GitHub](https://github.com/RunestoneInteractive) if you would like to use them to write your own resources.
#
# We also [welcome your support](https://runestone.academy/runestone/default/donate/10) to help keep Runestone growing.

# %% [markdown]
# # Getting started with building your dev environment
#
# * Create a brand new folder
# * Create python virtual environment
# ` python -m venv venv `
#
#  activate your virtual environment
#
#  `  source venv/bin/active `
#
#  you shound then get a prompt similar to
#
#  ` (venv)$~/code/jupyter$ `
#
#
# * Install jupyter note book using below commands:
#
#  `python -m pip install --upgrade pip`
#
#  `python -m pip install jupyter`
#
#  To start the notebook, run the following command at the command prompt:
#
#  `$ jupyter notebook`
#
#  You should then redirected to a new notebook and ready to start

# %% [markdown]
# `w = int()`

# %%
dir(w)

# %%
id(w)

# %%
text = '''Hello World!'''

# %% [markdown]
# # 2.4. Function Calls
#
# The Python interpreter can compute new values with function calls. You are familiar with the idea of functions from high school algebra. There you might define a function `f` by specifying how it transforms an input into an output, `f(x) = 3x + 2`. Then, you might write `f(5)` and expect to get the value 17.
#
# Python adopts a similar syntax for invoking functions. If there is a named function `foo` that takes a single input, we can invoke foo on the value 5 by writing `foo(5)`.
#
# There are many built-in functions available in Python. You’ll be seeing some in this chapter and the next couple of chapters.
#
# Functions are like factories that take in some material, do some operation, and then send out the resulting object.
# ![All Text!](https://fopp.umsi.education/books/published/fopp/_images/function_calls.gif)

# %%
def square(x):
   return x * x

def sub(x, y):
    
   x = square(x)
   return square(x) - y
print(sub(2, 3))
# Out:
# 13

# %% [markdown]
# # 2.5. Data Types
#
#
#
# If you are not sure what class (data type) a value falls into, Python has a function called **type** which can tell you.

# %%
print(type("Hello, World!"))
print(type(17))
print("Hello, World")
print(type(3.2))
# Out:
# <class 'str'>
# <class 'int'>
# Hello, World
# <class 'float'>

# %% [markdown]
# What about values like `"17"` and `"3.2"`? They look like numbers, but they are in quotation marks like strings.

# %%
print(type("17"))
print(type("3.2"))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# Strings in Python can be enclosed in either single quotes (`'`) or double quotes (`"`), or three of each (`'''` or `"""`)

# %%
print(type('This is a string.'))
print(type("And so is this."))
print(type("""and this."""))
print(type('''and even this...'''))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# Triple quoted strings can even span multiple lines:

# %%
print("""This message will span
several lines
of the text.""")
# Out:
# This message will span
# several lines
# of the text.

# %%
# Out:
# 42 17 56 34 11 4.35 32
# 3.4 hello 45

# %% [markdown]
# # 2.6. Type conversion functions
#
# Sometimes it is necessary to convert values from one type to another. Python provides a few simple functions that will allow us to do that. The functions `int`, `float` and `str` will **(attempt to)** convert their arguments into types int, float and str respectively. We call these **type conversion** functions.
#
# The int function can take a floating point number or a string, and turn it into an int. For floating point numbers, it discards the decimal portion of the number - a process we call truncation towards zero on the number line. Let us see this in action:
#
# * **TIP**: Watchout for corner cases!

# %%
print(3.14, int(3.14))
print(3.9999, int(3.9999))       # This doesn't round to the closest int!
print(3.0, int(3.0))
print(-3.999, int(-3.999))        # Note that the result is closer to zero

print("2345", int("2345"))        # parse a string to produce an int
print(17, int(17))                # int even works on integers
print(int("23bottles"))
# Out:
# 3.14 3
# 3.9999 3
# 3.0 3
# -3.999 -3
# 2345 2345
# 17 17
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <module>
#       6 print("2345", int("2345"))        # parse a string to produce an int
#       7 print(17, int(17))                # int even works on integers
# ----> 8 print(int("23bottles"))
#
# ValueError: invalid literal for int() with base 10: '23bottles'

# %%
print(float("123.45"))
print(type(float("123.45")))
# Out:
# 123.45
# <class 'float'>

# %%
print(str(17))
print(str(123.45))
print(type(str(123.45)))
# Out:
# 17
# 123.45
# <class 'str'>

# %% [markdown]
# One common operation where you might need to do a type conversion is when you are concatenating several strings together but want to include a numeric value as part of the final string. Because we can’t concatenate a string with an integer or floating point number, we will often have to convert numbers to strings before concatenating them.
#
# ![Text](https://fopp.umsi.education/books/published/fopp/_images/type_cast.gif)

# %% [markdown]
# # Example
# Extract input/output rate, and number of input/output packets on the below `show interface` output. Optionally extract number of input and output errors too.
# Convert each of the result into intiger and append each of them to a list. You can use the results in the future and deposite either into a database or draw using Matplotlib module.

# %%
data = '''
Cellular0/1/0 is up, line protocol is up 
  Hardware is LTE pluggable - Global Multimode LTE/DC-HSPA+/HSPA+/HSPA/UMTS/EDGE/GPRS
  Internet address is 10.112.218.18/32
  MTU 1500 bytes, BW 50000 Kbit/sec, DLY 20000 usec, 
     reliability 255/255, txload 3/255, rxload 3/255
  Encapsulation HDLC, loopback not set
  Keepalive not supported 
  DTR is pulsed for 1 seconds on reset
  Time to interface disconnect:  idle 00:00:29
  Last input 00:35:59, output 00:35:59, output hang never
  Last clearing of "show interface" counters never
  Input queue: 0/375/0/0 (size/max/drops/flushes); Total output drops: 0
  Queueing strategy: fifo
  Output queue: 0/40 (size/max)
  30 second input rate 713000 bits/sec, 79 packets/sec
  30 second output rate 729000 bits/sec, 89 packets/sec
     190485 packets input, 35525142 bytes, 0 no buffer
     Received 0 broadcasts (0 IP multicasts)
     0 runts, 0 giants, 0 throttles 
     0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
     193913 packets output, 44600328 bytes, 0 underruns
     Output 0 broadcasts (0 IP multicasts)
     0 output errors, 0 collisions, 1 interface resets
     0 unknown protocol drops
     0 output buffer failures, 0 output buffers swapped out
     0 carrier transitions
'''
d = []
for line in data.splitlines():
    d.append(line.split())
    
for i in d:
    print('_________________________________')
    for j in i:
        print(j)
#         if '30' and 'second' and 'rate' in j:
#             print(i)
# Out:
# _________________________________
# _________________________________
# Cellular0/1/0
# is
# up,
# line
# protocol
# is
# up
# _________________________________
# Hardware
# is
# LTE
# pluggable
# -
# Global
# Multimode
# LTE/DC-HSPA+/HSPA+/HSPA/UMTS/EDGE/GPRS
# _________________________________
# Internet
# address
# is
# 10.112.218.18/32
# _________________________________
# MTU
# 1500
# bytes,
# BW
# 50000
# Kbit/sec,
# DLY
# 20000
# usec,
# _________________________________
# reliability
# 255/255,
# txload
# 3/255,
# rxload
# 3/255
# _________________________________
# Encapsulation
# HDLC,
# loopback
# not
# set
# _________________________________
# Keepalive
# not
# supported
# _________________________________
# DTR
# is
# pulsed
# for
# 1
# seconds
# on
# reset
# _________________________________
# Time
# to
# interface
# disconnect:
# idle
# 00:00:29
# _________________________________
# Last
# input
# 00:35:59,
# output
# 00:35:59,
# output
# hang
# never
# ...

# %% [markdown]
# # Variables
#
# No specific apart from avoid using Python **keywords** such as and, as, assert, break, class, continue, def, del, elif, else, except, exec, finally, for etc...
#
# # Choosing the Right Variable Name
#
# Programmers generally choose names for their variables that are meaningful to the human readers of the program — they help the programmer document, or remember, what the variable is used for. Beginning programmers sometimes think it is funny to use strange or obscene names for their variables. This is not good practice and will not amuse your professor. Get in the habit of using meaningful names right away.

# %%
current_time_str = input("what is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int

final_answer = final_time_int % 24

print("The time after waiting is: ", final_answer)
# Out:
# what is the current time (in hours 0-23)?1
# How many hours do you want to wait2
# The time after waiting is:  3
